# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedShajiUddin/image_to_pencil_sketch.colab.mov/blob/main/syed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DESCRIPTION: IMAGE TO PENCIL SKETCH CONVERSION

# %% [markdown]
# NAME:- SYED SHAJI UDDIN

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt

# %%
image = io.imread("/content/sample_data/Dhoni.png")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGBA size=168x300>

# %%
grey_filter = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
cv2_imshow(grey_filter)
# grey scale image generated from real image
# Out:
# <PIL.Image.Image image mode=L size=168x300>

# %%
invert = cv.bitwise_not(grey_filter)
cv2_imshow(invert)
# grey scale is inverted
# Out:
# <PIL.Image.Image image mode=L size=168x300>

# %%
blur= cv.GaussianBlur(invert, (21,21), 0)
cv2_imshow(blur)
# inverted image is blured
#cv2.gaussianblur() function to apply Gaussian smoothing on the input source image
#any sharp edges in images are smoothed
# Out:
# <PIL.Image.Image image mode=L size=168x300>

# %%
invertedblur= cv.bitwise_not(blur)
cv2_imshow(invertedblur)
# blur image is inverted
# Out:
# <PIL.Image.Image image mode=L size=168x300>

# %%
sketch_filter= cv.divide (grey_filter, invertedblur, scale=225.0)
# using inverted blur image and grey filter image combination sketch image is being created
cv2_imshow(sketch_filter)
cv.imwrite("sketch.png", sketch_filter)
# Out:
# <PIL.Image.Image image mode=L size=168x300>
# True
